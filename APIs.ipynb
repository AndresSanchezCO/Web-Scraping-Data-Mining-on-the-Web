# %%
url_base = 'https://api.spotify.com/v1'

# %%
ep_artist = '/artist/{artist_id}'

# %%
id_b = '1TA5sGRlKUJXBN4ZyJuDIX'

# %%
url_base+ep_artist.format(artist_id=id_b)
# Out:
# 'https://api.spotify.com/v1/artist/1TA5sGRlKUJXBN4ZyJuDIX'

# %%
import requests

# %%
r = requests.get(url_base+ep_artist.format(artist_id=id_b))

# %%
r.status_code
# Out:
# 401

# %%
r.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type': 'client_credentials'}

# %%
headers = {'Authorization' : 'Basic OWIyZDg2MDMxMTQ2NGZiZWFkNDcwZDVkMDkyMDRmYTk6NzllNzk3ZGVhMjAzNGMyYzliMWFiNmE2YzIyNTdmODE='}

# %%
r = requests.post(token_url, data=params, headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQCmlyvub9MW40XyR6-zLrpfLMMqTemzfsgJsNVnxGnj0w1HExNEAfHYHKqSjUGQcbXaTPvLC-cPrQzRUZ3A7MrqjyuqwaeXgWqR3LjYfJc6PAK56R0',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
token = r.json()['access_token']
token
# Out:
# 'BQCmlyvub9MW40XyR6-zLrpfLMMqTemzfsgJsNVnxGnj0w1HExNEAfHYHKqSjUGQcbXaTPvLC-cPrQzRUZ3A7MrqjyuqwaeXgWqR3LjYfJc6PAK56R0'

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
r = requests.get(url_base+ep_artist.format(artist_id=id_b), headers=header)

# %%
r.status_code
# Out:
# 404

# %%
ep_artist ='https://api.spotify.com/v1/artists/{id}'
ep_albums = 'https://api.spotify.com/v1/artists/{id}/albums'
ep_album = 'https://api.spotify.com/v1/albums/{id}'
id_j= '1TA5sGRlKUJXBN4ZyJuDIX'
url=ep_artist.format(id= id_j)
url

#Al hacer esto obienen una url así: 

#'https://api.spotify.com/v1/artists/6J7biCazzYhU3gM9j1wfid'
# Out:
# 'https://api.spotify.com/v1/artists/1TA5sGRlKUJXBN4ZyJuDIX'

# %%
r = requests.get(url, headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1TA5sGRlKUJXBN4ZyJuDIX'},
#  'followers': {'href': None, 'total': 2297958},
#  'genres': ['reggaeton', 'urbano latino'],
#  'href': 'https://api.spotify.com/v1/artists/1TA5sGRlKUJXBN4ZyJuDIX',
#  'id': '1TA5sGRlKUJXBN4ZyJuDIX',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb261b09aa72e689605bb96758',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174261b09aa72e689605bb96758',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178261b09aa72e689605bb96758',
#    'width': 160}],
#  'name': 'Blessd',
#  'popularity': 73,
#  'type': 'artist',
#  'uri': 'spotify:artist:1TA5sGRlKUJXBN4ZyJuDIX'}

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q': "Blessd", 'type':'artist', 'market':'CO'}

# %%
busqueda = requests.get(url_busqueda, headers=header, params=search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Blessd&type=artist&market=CO&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TA5sGRlKUJXBN4ZyJuDIX'},
#     'followers': {'href': None, 'total': 2297958},
#     'genres': ['reggaeton', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/1TA5sGRlKUJXBN4ZyJuDIX',
#     'id': '1TA5sGRlKUJXBN4ZyJuDIX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb261b09aa72e689605bb96758',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174261b09aa72e689605bb96758',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178261b09aa72e689605bb96758',
#       'width': 160}],
#     'name': 'Blessd',
#     'popularity': 73,
#     'type': 'artist',
#     'uri': 'spotify:artist:1TA5sGRlKUJXBN4ZyJuDIX'},
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/1...
# 1  {'spotify': 'https://open.spotify.com/artist/6...
# 2  {'spotify': 'https://open.spotify.com/artist/7...
# 3  {'spotify': 'https://open.spotify.com/artist/4...
# 4  {'spotify': 'https://open.spotify.com/artist/6...
#
#                           followers  \
# 0  {'href': None, 'total': 2297958}
# 1        {'href': None, 'total': 4}
# 2  {'href': None, 'total': 1729606}
# 3    {'href': None, 'total': 48052}
# 4        {'href': None, 'total': 9}
#
#                                               genres  \
# 0                         [reggaeton, urbano latino]
# 1                                                 []
# 2  [reggaeton, trap colombiano, trap latino, urba...
# 3                                              [edm]
# 4                                                 []
#
#                                                 href                      id  \
# ...

# %%
df.sort_values(by='popularity', ascending=False).head().iloc[1]['id']
# Out:
# '1TA5sGRlKUJXBN4ZyJuDIX'

# %%
import base64

# %%
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id + ':' + client_secret, 'utf-8'))
    params = {'grant_type': 'client_credentials'}
    header = {'Authorization': 'Basic ' + str(encoded, 'utf-8')}
    r = requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
    if r.status_code != 200:
        print('Error en la autenticación', r.json())
        return None
    print('Token válido por {} segundos'.format(r.json()['expires_in']))
    return r.json()['access_token']

# %%
client_id = '9b2d860311464fbead470d5d09204fa9'

# %%
client_secret = '79e797dea2034c2c9b1ab6a6c2257f81'

# %%
token = get_token(client_id, client_secret)
# Out:
# Token válido por 3600 segundos

# %%
token
# Out:
# 'BQBk737Fs4_4-zODT1q3kv62eqE6eVIpHqOu_Ku2EkRTVPHva6JdagzcEqnRYg3wSR5-kLVz4_II-rMs0fN1V_QIe7_d6a4xnvL-DxLx61R-kxDUEeo'

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
id_b
# Out:
# '1TA5sGRlKUJXBN4ZyJuDIX'

# %%
params = {'country': 'CO'}

# %%
albums_b = requests.get(ep_albums.format(id=id_b), headers=header, params=params)

# %%
albums_b.status_code
# Out:
# 200

# %%
albums_b.json()['items'][0]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TA5sGRlKUJXBN4ZyJuDIX'},
#    'href': 'https://api.spotify.com/v1/artists/1TA5sGRlKUJXBN4ZyJuDIX',
#    'id': '1TA5sGRlKUJXBN4ZyJuDIX',
#    'name': 'Blessd',
#    'type': 'artist',
#    'uri': 'spotify:artist:1TA5sGRlKUJXBN4ZyJuDIX'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/4PR6koe67C7YosjAYriYh4'},
#  'href': 'https://api.spotify.com/v1/albums/4PR6koe67C7YosjAYriYh4',
#  'id': '4PR6koe67C7YosjAYriYh4',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2734c88949535e3089844c61219',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e024c88949535e3089844c61219',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048514c88949535e3089844c61219',
#    'width': 64}],
#  'is_playable': True,
#  'name': 'Siempre Blessd',
# ...

# %%
album_id = albums_b.json()['items'][0]['id']
album_id
# Out:
# '4PR6koe67C7YosjAYriYh4'

# %%
album_blessd = requests.get(ep_album.format(id=album_id)+'/tracks', headers=header, params=params)

# %%
album_blessd.status_code
# Out:
# 200

# %%
album_blessd.json()
# Out:
# {'href': 'https://api.spotify.com/v1/albums/4PR6koe67C7YosjAYriYh4/tracks?offset=0&limit=20',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TA5sGRlKUJXBN4ZyJuDIX'},
#      'href': 'https://api.spotify.com/v1/artists/1TA5sGRlKUJXBN4ZyJuDIX',
#      'id': '1TA5sGRlKUJXBN4ZyJuDIX',
#      'name': 'Blessd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1TA5sGRlKUJXBN4ZyJuDIX'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
# ...

# %%
lista_albums = [(albums_b['id'],albums_b['name']) for albums_b in albums_b.json()['items']]
lista_albums
# Out:
# [('4PR6koe67C7YosjAYriYh4', 'Siempre Blessd'),
#  ('50SdnzlrXUMadt9JYeaJSh', 'Hecho En Medellín'),
#  ('4KJWnsQKwDIbcUAV3i7m5P', 'La Parranda (RMX)'),
#  ('4ahLGrhxB0ME8dtGoPI4iR', 'BILLBOARD'),
#  ('0bKvyVdhfsb0hLcN7oVUpv', 'Ojitos Rojos (Remix)'),
#  ('6B5dqaafC0ygHJ8dUW1FOs', 'Palabras Sobran'),
#  ('3fAhHCHL12IjUVUMmImIUs', 'Verano'),
#  ('4UzpURCRisCfPfYZ96rsLE', 'Las Morras'),
#  ('2aXzhaV9TkNFsmUnkOUBy9', 'Fendi & Valentino'),
#  ('3KdT1P24jy6A1n8N6juvxy', 'VICE'),
#  ('2961gn3NRzleGQPWL0wJf2', 'AP'),
#  ('49nXirxfEoHGlEkrzCp2tE', 'Mi Gata (Remix)'),
#  ('2VJLr9Szd9xv7Dcrey5oOd', 'Instagram (Remix)'),
#  ('0MPj6gzF6jNWOZLHmqMWtk', 'Qué Rico (feat. El Clooy) [Remix]'),
#  ('26gxlnGOcwQsUheyskEuMV', 'Fumando'),
#  ('5S7g9lFAwX5rUAM2I4idTS', 'Bonita'),
#  ('7rm64Fm5KyyffZ5w0lFwpV', 'El Mensaje'),
#  ('76mNc50Njn9XlFMMYvh1G3', 'Energía'),
#  ('5QP7KzyD4Q78s7hpqVA5Wf', '10 PM'),
#  ('0UKMqy1QBgwAgfwIsWmOsR', '10 PM (Popular)')]

# %%
album_blessd.json()['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TA5sGRlKUJXBN4ZyJuDIX'},
#     'href': 'https://api.spotify.com/v1/artists/1TA5sGRlKUJXBN4ZyJuDIX',
#     'id': '1TA5sGRlKUJXBN4ZyJuDIX',
#     'name': 'Blessd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1TA5sGRlKUJXBN4ZyJuDIX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
# ...

# %%
[(album_blessd['id'], album_blessd['name']) for album_blessd in album_blessd.json()['items']]
# Out:
# [('6oPzWRP2VSZf8EMq5WeL03', 'Barrio Antioquia'),
#  ('12RaiccXZ5yIDrHt4c5ngZ', 'Que Duro'),
#  ('3LbiVjqY2chZ0q9oOwbluK', 'Ojitos Rojos'),
#  ('4WTF4MkWJSEeWhTNk3ywPT', 'Más Allá'),
#  ('73lC7gD1EKomxcuXRn7qRR', 'Exclusive'),
#  ('4C8KFz9tPZjIsMfFh9NnJ9', 'Europa'),
#  ('0MWYdCwez4qHJok0df6hbV', 'Dime'),
#  ('2NrpiW6Kc1XPm9AzmvuxEa', 'Solitario'),
#  ('6HOMz6FCZqLjTg3Eey0vm2', 'Instagram - Remix'),
#  ('3JYw9n3rJTVQryVz1rwlH4', 'Ziploc (Blessd Version)'),
#  ('2wmusRbeSfEkMKjT3wG57l', 'Bottega'),
#  ('1xUd3t6zmrAC08LrWKEBrC', 'Bandida'),
#  ('2TCklWS3S4Zg6e2m2MBoYm', 'Tendencia Global')]

# %%
def obtener_discografia(artist_id, token, return_name = False, page_lilmit = 50, country = None ):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    header = {'authorization': f'Bearer {token}'}
    params = {'limit': page_lilmit, 'offset': 0, 'country': country}
    lista = []
    r = requests.get(url, headers=header, params=params)

    if r.status_code != 200:
        print('Error en la consulta', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
    
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %%
def obtener_tracks(album_id, token, return_name=False, page_limit=50, market=None):
    url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    header = {'authorization': f'Bearer {token}'}
    params = {'limit': page_limit, 'offset': 0, 'market': market}
    lista = []
    r = requests.get(url, headers=header, params=params)

    if r.status_code != 200:
        print('Error en la consulta', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
    
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %%
for album in obtener_discografia(id_b, token, return_name=True, country='CO'):
    print(album[1])
    for track in obtener_tracks(album[0], token, return_name=True, market='CO'):
        print('\t', track[1])
# Out:
# Siempre Blessd
# 	 Barrio Antioquia
# 	 Que Duro
# 	 Ojitos Rojos
# 	 Más Allá
# 	 Exclusive
# 	 Europa
# 	 Dime
# 	 Solitario
# 	 Instagram - Remix
# 	 Ziploc (Blessd Version)
# 	 Bottega
# 	 Bandida
# 	 Tendencia Global
# Hecho En Medellín
# 	 Envidia
# 	 Medallo
# 	 Otro Día
# 	 Regaños
# 	 Coroné
# 	 Quien TV
# 	 Hace Tiempo
# 	 La Noche
# 	 Siempre
# 	 Puñeta
# La Parranda (RMX)
# 	 La Parranda - RMX
# BILLBOARD
# 	 BILLBOARD
# 	 VUELA
# Ojitos Rojos (Remix)
# 	 Ojitos Rojos - Remix
# Palabras Sobran
# 	 Palabras Sobran
# Verano
# 	 Verano
# Las Morras
# 	 Las Morras
# Fendi & Valentino
# 	 Fendi & Valentino
# 	 VICE
# 	 AP
# VICE
# 	 VICE
# 	 AP
# AP
# 	 AP
# Mi Gata (Remix)
# 	 Mi Gata - Remix
# Instagram (Remix)
# 	 Instagram - Remix
# Qué Rico (feat. El Clooy) [Remix]
# 	 Qué Rico (feat. El Clooy) - Remix
# Fumando
# 	 Fumando
# Bonita
# 	 Bonita
# El Mensaje
# 	 El Mensaje
# Energía
# 	 Energía
# 10 PM
# 	 10 PM
# 10 PM (Popular)
# 	 10 PM - Popular
# Instagram
# ...

# %%
preview_url = 'https://p.scdn.co/mp3-preview/b6015cd9ec5ea71a0a0c0a51f6b8db1f1f2233a4?cid=9b2d860311464fbead470d5d09204fa9'

# %%
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
preview.content
# Out:
# b'ID3\x04\x00\x00\x00\x00\x15CGEOB\x00\x00\nT\x00\x00\x00application/json\x00metadata.json\x00\x00{"start_time": 68.645, "loop_duration": 16.84124, "crossfade_duration": 0, "beats": [0.0, 0.5360700000000094, 1.0641999999999996, 1.5914100000000104, 2.1181700000000063, 2.6458900000000085, 3.171289999999999, 3.695779999999999, 4.2221700000000055, 4.749530000000007, 5.274110000000007, 5.797319999999999, 6.321970000000007, 6.848100000000002, 7.374300000000005, 7.901070000000004, 8.428870000000003, 8.958219999999997, 9.48724, 10.014989999999997, 10.54146, 11.067599999999999, 11.5929, 12.117840000000001, 12.64331, 13.168850000000006, 13.69398000000001, 14.218240000000009, 14.741600000000005, 15.26642000000001, 15.790350000000004, 16.31671, 16.84124, 17.368160000000003, 17.89327, 18.41937, 18.944590000000005, 19.471280000000007, 19.994740000000007, 20.523430000000005, 21.04938, 21.57821, 22.108500000000006, 22.639780000000002, 23.168260000000004, 23.696759999999998, 24.222920000000002, 24.75
# ...

# %%
import IPython.display as ipd

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
